# %% [markdown]
# <a href="https://colab.research.google.com/github/easoncheng1234-spec/ytp-demo/blob/main/class02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computer Vision

# %%
import cv2 # opencv
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/ytp/dan-begel-SoLWkVvF7cU-unsplash.jpg"
image = cv2.imread(path)
print(type(image))
print(image.shape) # h, w, c
print(image)
# Out:
# <class 'numpy.ndarray'>
# (3034, 4551, 3)
# [[[188 206 199]
#   [185 203 196]
#   [183 201 194]
#   ...
#   [184 194 164]
#   [187 197 167]
#   [188 198 168]]
#
#  [[195 213 206]
#   [189 207 200]
#   [185 203 196]
#   ...
#   [185 195 165]
#   [188 198 168]
#   [190 200 170]]
#
#  [[189 207 200]
#   [189 207 200]
#   [191 209 202]
#   ...
#   [187 195 164]
#   [189 197 166]
#   [190 198 167]]
#
#  ...
#
#  [[ 54 112 177]
#   [ 41  99 164]
#   [ 48 106 171]
#   ...
#   [ 70 130 196]
#   [ 78 138 204]
#   [ 81 139 205]]
#
#  [[ 44 104 170]
#   [ 45 105 171]
#   [ 39  99 165]
#   ...
#   [ 77 135 201]
#   [ 83 141 207]
#   [ 85 143 209]]
#
#  [[ 41 101 167]
#   [ 37  97 163]
#   [ 37  97 163]
#   ...
#   [ 81 139 205]
#   [ 86 144 210]
#   [ 86 144 210]]]

# %%
plt.imshow(image) # cv2 (B, G, R)
plt.show()

# %%
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()
